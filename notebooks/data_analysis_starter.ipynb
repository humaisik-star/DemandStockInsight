# %% [markdown]
# # Starter Data Analysis Notebook
#
# Use this notebook to load your dataset, explore its structure, and run initial analysis. Place your data file in the `data/` folder and update the filename below.

# %%
import pandas as pd
from pathlib import Path

base_dir = Path.cwd()
data_dir = base_dir / 'data'
if not data_dir.exists():
    data_dir = base_dir.parent / 'data'

candidates = [
    data_dir / 'inventory_demand_forecasting_dataset.csv',
    data_dir / 'demand_forecasting.csv',
]

data_path = next((p for p in candidates if p.exists()), None)
if data_path is None:
    raise FileNotFoundError(f'No dataset file found in {data_dir}')

print('Data file:', data_path)
df = pd.read_csv(data_path)
df.head()
# Out:
# Data file: /Users/mac/Demand And Stock Analysis ML  /data/inventory_demand_forecasting_dataset.csv
#          date store_id product_id  price  promotion  demand
# 0  2024-01-01  Store_1  Product_A  39.28          1      85
# 1  2024-01-01  Store_2  Product_A  23.35          0      95
# 2  2024-01-01  Store_3  Product_A  12.26          0      44
# 3  2024-01-01  Store_1  Product_B  17.34          0      21
# 4  2024-01-01  Store_2  Product_B  10.28          0      95

# %% [markdown]
# ## Initial dataset summary
#
# Run the next cell to see the dataset shape and basic info.

# %%
print('Shape:', df.shape)
print('Columns:')
print(df.columns.tolist())
print('Info:')
print(df.info())
print('Describe:')
print(df.describe(include='all'))
# Out:
# Shape: (4380, 6)
# Columns:
# ['date', 'store_id', 'product_id', 'price', 'promotion', 'demand']
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        4380 non-null   object
#  1   store_id    4380 non-null   object
#  2   product_id  4380 non-null   object
#  3   price       4380 non-null   float64
#  4   promotion   4380 non-null   int64
#  5   demand      4380 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 205.4+ KB
# None
# Describe:
#               date store_id product_id        price    promotion       demand
# count         4380     4380       4380  4380.000000  4380.000000  4380.000000
# unique         365        3          4          NaN          NaN          NaN
# top     2024-01-01  Store_1  Product_A          NaN          NaN          NaN
# ...

# %% [markdown]
# ## Basic visual checks
#
# Run this cell if your dataset contains numeric columns.

# %%
import matplotlib.pyplot as plt

try:
    import seaborn as sns
except ModuleNotFoundError:
    sns = None

numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
print('Numeric columns:', numeric_cols)

if len(numeric_cols) > 0:
    corr = df[numeric_cols].corr()

    plt.figure(figsize=(12, 6))
    if sns is not None:
        sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
    else:
        plt.imshow(corr, cmap='coolwarm')
        plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
        plt.yticks(range(len(corr.index)), corr.index)
        for i in range(corr.shape[0]):
            for j in range(corr.shape[1]):
                plt.text(j, i, f'{corr.iloc[i, j]:.2f}', ha='center', va='center')
    plt.title('Numeric feature correlation matrix')
    plt.show()

    plt.figure(figsize=(12, 8))
    df[numeric_cols].hist(bins=20)
    plt.tight_layout()
    plt.show()
else:
    print('No numeric columns found for visualization.')
# Out:
# Numeric columns: ['price', 'promotion', 'demand']
